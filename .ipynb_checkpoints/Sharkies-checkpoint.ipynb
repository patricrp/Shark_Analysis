# %%
#Hipótesis. Dado que el surf nació en la costa oeste de EEUU, se plantea que el mayor número de ataques de tiburones a surfistas se ha producido en la costa oeste de EEUU.

#Buscar:
#Filtrar el DataFrame para la actividad surf
#Filtrar el DataFrame para la costa oeste. Country == USA  & Areas: Alaska, Hawai, California, Oregon y Washington
#La suma del número de casos de 'Surfing' de la costa oeste debe ser mayor a la suma de casos de 'Surfing' en otros países u otras áreas de EEUU
#Puede ser interesante buscar la moda de Area por Country en Surfing
#Puede ampliarse para saber si verano es la época del año con mayor número de ataques, ya que agosto y septiembre son los mejores meses para surfear

# %%
#Limpieza de datos.

#Crear un DataFrame a partir del DataFrame original con las columnas más interesantes para analizar la hipótesis
#Columnas de interés: Case Number, Country, Area, Date, Year, Location, Activity, 'Injury', 'Fatal (Y/N)'

#Renombrar las columnas para que no tengan espacio en el nombre

#Revisar los datos duplicados en Case Number, si no están duplicados en todos los campos, asignar una letra al final. O eliminar los 32 registros.

#Eliminar en los países los '?'

#En Países, reescribir a primera en mayúscula y el resto en minúscula

#Agrupar por continente

#Revisar los años. Si los dos últimos dígitos de 'Year' no coincide con los dos últimos dígitos de 'Date', sobreescribir 'Date' con el año.

# %%
#Importar módulos

import pandas as pd
import numpy as np
import re

# %%
#Creación de la base de datos

df = pd.read_csv('input/GSAF5.csv', engine = 'python')
df.head(10)
# Out:
#     Case Number       Date  Year        Type        Country  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3    2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4    2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5  2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6    2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7    2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8    2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9  2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
#
#                 Area                                         Location  \
# 0            Florida                 New Smyrna Beach, Volusia County
# 1            Florida                 New Smyrna Beach, Volusia County
# 2            Florida                 New Smyrna Beach, Volusia County
# 3           Victoria                                 Thirteenth Beach
# 4           Victoria                                      Bells Beach
# 5  Western Australia                                          Bunbury
# 6            Florida                    Ponte Vedra, St. Johns County
# 7             Hawaii                                     Makaha, Oahu
# 8     North Province                                           Koumac
# 9     South Carolina  Kingston Plantation, Myrtle Beach, Horry County
#
#           Activity                    Name Sex   ...          Species   \
# 0          Surfing                    male    M  ...               NaN
# 1          Surfing          Chucky Luciano    M  ...               NaN
# 2          Surfing                    male    M  ...               NaN
# 3          Surfing         Rory Angiolella    M  ...               NaN
# 4          Surfing                    male    M  ...         2 m shark
# 5          Fishing  Occupant: Ben Stratton  NaN  ...               NaN
# 6           Wading                    male    M  ...    3' to 4' shark
# 7         Swimming                  female    F  ...  Tiger shark, 10?
# 8     Kite surfing            David Jewell    M  ...               NaN
# 9  Boogie boarding          Rylie Williams    F  ...               NaN
#
#         Investigator or Source                        pdf  \
# 0  Orlando Sentinel, 9/19/2016       2016.09.18.c-NSB.pdf
# 1  Orlando Sentinel, 9/19/2016   2016.09.18.b-Luciano.pdf
# 2  Orlando Sentinel, 9/19/2016       2016.09.18.a-NSB.pdf
# 3           The Age, 9/18/2016  2016.09.17-Angiolella.pdf
# 4           The Age, 9/16/2016  2016.09.16-BellsBeach.pdf
# 5   West Australian, 9/15/2016      2016.09.15.R-boat.pdf
# 6          News4Jax, 9/11/2016  2016.09.11-PonteVedra.pdf
# 7    Hawaii News Now, 9/7/2016        2016.09.07-Oahu.pdf
# 8       TVANouvelles, 9/6/2016      2016.09.06-Jewell.pdf
# 9            C. Creswell, GSAF  2016.09.05.b-Williams.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.15.R
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.11
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.07
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.06
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.05.b
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0  2016.09.18.c           5993         NaN         NaN
# 1  2016.09.18.b           5992         NaN         NaN
# 2  2016.09.18.a           5991         NaN         NaN
# 3    2016.09.17           5990         NaN         NaN
# 4    2016.09.15           5989         NaN         NaN
# 5  2016.09.15.R           5988         NaN         NaN
# 6    2016.09.11           5987         NaN         NaN
# 7    2016.09.07           5986         NaN         NaN
# 8    2016.09.06           5985         NaN         NaN
# 9  2016.09.05.b           5984         NaN         NaN
#
# [10 rows x 24 columns]

# %%
#Conocer la base de datos

df.shape
# Out:
# (5992, 24)

# %%
#Conocer cuántos registros nulos hay en cada columna

df.isnull().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
#Conocer las columnas
df.columns

#Comprobamos que hay columnas que tienen espacio en el nombre. 
#Eliminar el espacio de aquellos con la función str.rstrip()
df.columns = df.columns.str.rstrip()
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#Seleccionar las columnas necesarias para el estudio de la hipótesis: Case Number, Country, Area, Date, Year, Location, Activity, 'Injury', 'Fatal (Y/N)'

shark_df = df[['Case Number', 'Date', 'Year', 'Country', 'Area', 'Location',
       'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)']]
shark_df.head()
# Out:
#     Case Number       Date  Year    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex  Age  \
# 0  New Smyrna Beach, Volusia County  Surfing             male   M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano   M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male   M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella   M  NaN
# 4                       Bells Beach  Surfing             male   M  NaN
#
#                                   Injury Fatal (Y/N)
# 0                  Minor injury to thigh           N
# 1                   Lacerations to hands           N
# 2               Lacerations to lower leg           N
# 3           Struck by fin on chest & leg           N
# 4  No injury: Knocked off board by shark           N

# %%
#Seleccionar la columna 'Case Number' como referente del índice

#Revisar si existen duplicados en la columna 'Case Number'

shark_df['Case Number'].duplicated().value_counts()
# Out:
# False    5976
# True       16
# Name: Case Number, dtype: int64

# %%
#Existen 16 'Case Number' duplicados. 
#Comprobar si son el mismo caso. Para ser el mismo caso se establece que debe ser misma 'Date', mismo 'Country', misma 'Area' y misma 'Activity'

#shark_df[shark_df['Case Number'].duplicated(keep=False)][['Case Number', 'Date', 'Country', 'Area', 'Activity']]

#Crear una función para que revise si son dos 'Case Number' iguales compruebe los otros campos. Si los campos son iguales, elimina uno de los dos. si los campos son distintos, añade 'x' al final de 'Case Number'. Se añade 'x' porque en el caso de que haya un 'Case Number' similar con una letra, no sea la b o c. 



#duplicates = shark_df[shark_df['Case Number'].duplicated(keep=False)]['Case Number'].tolist()
set_duplicates = set(duplicates)
set_duplicates

for dup in set_duplicates:
    a=shark_df.loc[(shark_df['Case Number'] == dup)]
    display(a)
    
    break
   

#shark_df.drop_duplicates(keep='first')
# Out:
#     Case Number       Date  Year Country     Area  \
# 300  2014.08.02  02-Aug-14  2014     USA  Florida
# 301  2014.08.02  02-Aug-14  2014     USA  Florida
#
#                                  Location         Activity  \
# 300  South of Cocoa Beach, Brevard County          Surfing
# 301           Table Beach, Brevard County  Boogie boarding
#
#                    Name Sex  Age               Injury Fatal (Y/N)
# 300                male   M  50s          Foot bitten           N
# 301  Christian Sanhueza   M    8  Laceration to ankle           N

# %%
#Revisar los ataques que tengan una 'Activity' no registrada
shark_df['Activity'].isnull().value_counts() 

#527 ataques no indican cuál fue la 'Activity'
# Out:
# False    5465
# True      527
# Name: Activity, dtype: int64

# %%
#Para inducir si alguno de esos 527 ataques que no tienen 'Activity' declarada han podido ser a surfistas...
#Analizar 'Injury' a surfistas
#shark_df[(shark_df['Activity'] == 'Surfing')]['Injury'].value_counts()

#Foot bitten y board son los valores que más se repiten
#Comprobar si en otras 'Activity' foot y board también aparecen con mucha frecuencia

#shark_df['Injury'].value_counts()

#Foot bitten aparece 82 veces
shark_df[(shark_df['Injury'].str.contains(' board ', na=False, regex=False))] #Se incluye na=False para que los nulos los pase a False.
# Out:
#        Case Number         Date  Year               Country  \
# 4       2016.09.15    16-Sep-16  2016             AUSTRALIA
# 10    2016.09.05.a    05-Sep-16  2016             AUSTRALIA
# 18      2016.08.06    06-Aug-16  2016                   USA
# 24      2016.07.26    26-Jul-16  2016             AUSTRALIA
# 50      2016.06.07    07-Jun-16  2016                   USA
# ...            ...          ...   ...                   ...
# 3741    1960.08.29    29-Aug-60  1960               SENEGAL
# 4168    1952.12.24    24-Dec-52  1952             AUSTRALIA
# 4353    1947.04.06    06-Apr-47  1947             AUSTRALIA
# 4920    1926.04.22    22-Apr-26  1926  SOUTH ATLANTIC OCEAN
# 5749    1852.02.26  26-Feb-1852  1852          SOUTH AFRICA
#
#                        Area                                        Location  \
# 4                  Victoria                                     Bells Beach
# 10        Western Australia                                        Injidup
# 18                   Hawaii                                            Maui
# 24          New South Wales                          Sharpes Beach, Ballina
# 50           South Carolina                  Folly Beach, Charleston County
# ...                     ...                                             ...
# 3741     Cap-Vert Peninsula                                       off Dakar
# 4168               Victoria                   Portsea Beach, near Melbourne
# 4353        New South Wales                                      Palm Beach
# 4920  South of the Equator   Steamship bound from Cape Town to Philadelphia
# 5749  Western Cape Province                                    Danger Point
#
#                                                Activity  \
# 4                                               Surfing
# 10                                              Surfing
# 18                                    SUP Foil boarding
# 24                                              Surfing
# 50                                              Surfing
# ...                                                 ...
# 3741  Air disaster: crash of Air France Super Conste...
# 4168                           Lying prone on surfboard
# 4353                                            Surfing
# 4920               Fell overboard from SS Ripley Castle
# 5749                  Wreck of the steamship Birkenhead
#
#                           Name  Sex  Age  \
# 4                         male    M  NaN
# 10               Fraser Penman    M  NaN
# 18               Connor Baxter    M   21
# 24     Curran See & Harry Lake    M   18
# 50                Jack O'Neill    M   27
# ...                        ...  ...  ...
# 3741                       NaN  NaN  NaN
# 4168              Bernard Bade    M  NaN
# 4353                  Max Watt    M   17
# 4920  Thomas (or Tony) Madison    M   26
# 5749                       NaN    M  NaN
#
#                                                  Injury Fatal (Y/N)
# 4                 No injury: Knocked off board by shark           N
# 10              No inury, board broken in half by shark           N
# 18                     No inury, shark & board collided           N
# 24    No injury. Leg rope severed, knocked off board...           N
# 50                             No injury, board damaged           N
# ...                                                 ...         ...
# 3741  All 63 on board perished when the aircraft hit...           Y
# 4168                   No injury, board bumped by shark           N
# 4353                  No injury, board scraped by shark           N
# 4920  When taken back on board 2 hours later both le...           N
# 5749  FATAL. All of the women & children on board su...           Y
#
# [97 rows x 12 columns]

# %%
#Filtrar el DataFrame solo por la actividad 'Surfing'

shark_df = shark_df[shark_df.Activity == 'Surfing']
shark_df.head()
# Out:
#     Case Number       Date  Year    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex  Age  \
# 0  New Smyrna Beach, Volusia County  Surfing             male   M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano   M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male   M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella   M  NaN
# 4                       Bells Beach  Surfing             male   M  NaN
#
#                                   Injury Fatal (Y/N)
# 0                  Minor injury to thigh           N
# 1                   Lacerations to hands           N
# 2               Lacerations to lower leg           N
# 3           Struck by fin on chest & leg           N
# 4  No injury: Knocked off board by shark           N

# %%
#Conocer cuántos ataques a surfistas ha habido
